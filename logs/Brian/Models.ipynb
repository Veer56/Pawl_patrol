# %% [markdown]
# ## Model 1

# %%
# create the CNN model by adding the layers
model=tf.keras.Sequential()
model.add(tf.keras.layers.Conv2D(64,(3,3),activation='relu',input_shape=(128,128,3),padding='same'))
model.add(tf.keras.layers.MaxPool2D((2,2)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(512,activation='relu'))
model.add(tf.keras.layers.Dropout(0.1))
model.add(tf.keras.layers.Dense(256,activation='relu'))
model.add(tf.keras.layers.Dense(128,activation='relu'))
model.add(tf.keras.layers.Dense(1,activation=None))

# train the model and evaluate it with the test_data
train_and_evaluate(model, image_train, label_train, image_test, label_test, epochs=20)

# %% [markdown]
# loss: 343.9879
# RootMeanSquaredError: 18.5205
# val_loss: 417.7448
# val_RootMeanSquaredError: 20.4311

# %% [markdown]
# ## Model 2
# - added dropout layers after every Dense layer --> prevent overfit

# %%
# create the CNN model by adding the layers
model=tf.keras.Sequential()
model.add(tf.keras.layers.Conv2D(64,(3,3),activation='relu',input_shape=(128,128,3),padding='same'))
model.add(tf.keras.layers.MaxPool2D((2,2)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(512,activation='relu'))
model.add(tf.keras.layers.Dropout(0.1))
model.add(tf.keras.layers.Dense(256,activation='relu'))
model.add(tf.keras.layers.Dropout(0.1))
model.add(tf.keras.layers.Dense(128,activation='relu'))
model.add(tf.keras.layers.Dropout(0.1))
model.add(tf.keras.layers.Dense(1,activation=None))

# train the model and evaluate it with the test_data
train_and_evaluate(model, image_train, label_train, image_test, label_test, epochs=20)

# %% [markdown]
# loss: 589.2401
# RootMeanSquaredError: 24.2776
# val_loss: 506.9625
# val_RootMeanSquaredError: 22.5723

# %% [markdown]
# ## Model 3
# - removed dropouts
# - added Batchnormalization

# %%
# create the CNN model by adding the layers
model=tf.keras.Sequential()
model.add(tf.keras.layers.Conv2D(64,(3,3),activation='relu',input_shape=(128,128,3),padding='same'))
model.add(BatchNormalization())
model.add(tf.keras.layers.MaxPool2D((2,2)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(512,activation='relu'))
model.add(tf.keras.layers.Dropout(0.1))
model.add(tf.keras.layers.Dense(256,activation='relu'))
model.add(tf.keras.layers.Dense(128,activation='relu'))
model.add(tf.keras.layers.Dense(1,activation=None))

# train the model and evaluate it with the test_data
train_and_evaluate(model, image_train, label_train, image_test, label_test, epochs=20)

# %% [markdown]
# loss: 33.4382
# RootMeanSquaredError: 5.7680
# val_loss: 506.3454
# val_RootMeanSquaredError: 22.5512
#
# ![image.png](attachment:image.png)
#
# Validation not decreasing

# %% [markdown]
# ## Model 4
# - added back dropouts

# %%
# create the CNN model by adding the layers
model=tf.keras.Sequential()
model.add(tf.keras.layers.Conv2D(64,(3,3),activation='relu',input_shape=(128,128,3),padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPool2D((2,2)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(512,activation='relu'))
model.add(tf.keras.layers.Dropout(0.1))
model.add(tf.keras.layers.Dense(256,activation='relu'))
model.add(tf.keras.layers.Dropout(0.1))
model.add(tf.keras.layers.Dense(128,activation='relu'))
model.add(tf.keras.layers.Dropout(0.1))
model.add(tf.keras.layers.Dense(1,activation=None))

# train the model and evaluate it with the test_data
train_and_evaluate(model, image_train, label_train, image_test, label_test, epochs=20)

# %% [markdown]
# loss: 65.9061
# RootMeanSquaredError: 8.1224
# val_loss: 506.3507
# val_RootMeanSquaredError: 22.5588

# %% [markdown]
# ## Model 5
# - increase dropout values

# %%
# create the CNN model by adding the layers
model=tf.keras.Sequential()
model.add(tf.keras.layers.Conv2D(64,(3,3),activation='relu',input_shape=(128,128,3),padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPool2D((2,2)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(512,activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(256,activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(128,activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(1,activation=None))

# train the model and evaluate it with the test_data
train_and_evaluate(model, image_train, label_train, image_test, label_test, epochs=20)

# %% [markdown]
# loss: 317.3452
# RootMeanSquaredError: 17.8191
# val_loss: 583.8023
# val_RootMeanSquaredError: 24.0088
# ![image.png](attachment:image.png)
#
# seems like it's going the right way

# %% [markdown]
# ## Model 6
# - increasing epochs

# %%
# create the CNN model by adding the layers
model=tf.keras.Sequential()
model.add(tf.keras.layers.Conv2D(64,(3,3),activation='relu',input_shape=(128,128,3),padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPool2D((2,2)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(512,activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(256,activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(128,activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(1,activation=None))

# train the model and evaluate it with the test_data
train_and_evaluate(model, image_train, label_train, image_test, label_test, epochs=50)

# %% [markdown]
# loss: 168.8923
# RootMeanSquaredError: 12.9940
# val_loss: 666.3548
# val_RootMeanSquaredError: 25.8505
# ![image.png](attachment:image.png)
# still overfitting

# %% [markdown]
# ## Model 7
# - adding data augmentation

# %%
# create the CNN model by adding the layers
model=tf.keras.Sequential()
model.add(tf.keras.layers.Conv2D(64,(3,3),activation='relu',input_shape=(128,128,3),padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPool2D((2,2)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(512,activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(256,activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(128,activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(1,activation=None))

# add augmentations for the data
augment = {'width_shift_range': 0.25, 'height_shift_range': 0.25}

# train the model and evaluate it with the test_data
train_and_evaluate(model, image_train, label_train, image_test, label_test, epochs=50, augment=augment)

# %% [markdown]
# loss: 173.6985
# RootMeanSquaredError: 13.1759
# val_loss: 779.2206
# val_RootMeanSquaredError: 27.8311
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Model 8
# - tried a model I saw on kaggle

# %%
# create the CNN model by adding the layers
model=tf.keras.Sequential()
model.add(tf.keras.layers.Conv2D(16,(7,7), strides = (2,2),activation='relu',input_shape=(128,128,3),padding='same'))
model.add(tf.keras.layers.Conv2D(32,(3,3),activation='relu',input_shape=(128,128,3),padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Conv2D(32,(3,3), strides = (2,2), activation='relu',input_shape=(128,128,3),padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.25))

model.add(tf.keras.layers.Conv2D(64,(3,3),activation='relu',input_shape=(128,128,3),padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Conv2D(64,(3,3), strides = (2,2), activation='relu',input_shape=(128,128,3),padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.25))

model.add(tf.keras.layers.Conv2D(128,(3,3),activation='relu',input_shape=(128,128,3),padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(tf.keras.layers.Conv2D(128,(3,3), activation='relu',input_shape=(128,128,3),padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.25))

model.add(tf.kears.layers.Flatten())
model.add(tf.keras.layers.Dense(512, activation = 'relu'))
model.add(tf.keras.layers.Dropout(0.5))

model.add(tf.keras.layers.Dense(1))

# add augmentations for the data
augment = {'width_shift_range': 0.25, 'height_shift_range': 0.25}

# train the model and evaluate it with the test_data
train_and_evaluate(model, image_train, label_train, image_test, label_test, epochs=50, augment=augment)

# %% [markdown]
# loss: 58.1579
# RootMeanSquaredError: 7.6282
# val_loss: 541.4236
# val_RootMeanSquaredError: 23.3024
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Model 9
# - trying the same model with more augmentation

# %%
# create the CNN model by adding the layers
model=tf.keras.Sequential()
model.add(tf.keras.layers.Conv2D(16,(7,7), strides = (2,2),activation='relu',input_shape=(128,128,3),padding='same'))
model.add(tf.keras.layers.Conv2D(32,(3,3),activation='relu',input_shape=(128,128,3),padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Conv2D(32,(3,3), strides = (2,2), activation='relu',input_shape=(128,128,3),padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.25))

model.add(tf.keras.layers.Conv2D(64,(3,3),activation='relu',input_shape=(128,128,3),padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Conv2D(64,(3,3), strides = (2,2), activation='relu',input_shape=(128,128,3),padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.25))

model.add(tf.keras.layers.Conv2D(128,(3,3),activation='relu',input_shape=(128,128,3),padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(tf.keras.layers.Conv2D(128,(3,3), activation='relu',input_shape=(128,128,3),padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.25))

model.add(tf.kears.layers.Flatten())
model.add(tf.keras.layers.Dense(512, activation = 'relu'))
model.add(tf.keras.layers.Dropout(0.5))

model.add(tf.keras.layers.Dense(1))

# add augmentations for the data
augment = {'width_shift_range': 0.25, 'height_shift_range': 0.25, 'zoom_range' : 0.15, 'rotation_range' : 15, 'shear_range' : 0.1, 'horizontal_flip' : True}

# train the model and evaluate it with the test_data
train_and_evaluate(model, image_train, label_train, image_test, label_test, epochs=50, augment=augment)

# %% [markdown]
# loss: 56.8892
# RootMeanSquaredError: 7.5408
# val_loss: 475.6704
# val_RootMeanSquaredError: 21.8686
# ![image.png](attachment:image.png)

# %% [markdown]
# ## model 10
# - trying other kaggle model

# %%
# create the CNN model by adding the layers
model = tf.keras.Sequential()

model.add(tf.keras.layers.Conv2D(32, (5, 5), input_shape=(128, 128, 3)))

model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
model.add(tf.keras.layers.Dropout(0.4))

model.add(tf.keras.layers.Conv2D(64, (3, 3)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
model.add(tf.keras.layers.Dropout(0.4))

model.add(tf.keras.layers.Conv2D(64, (3, 3)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
model.add(tf.keras.layers.Dropout(0.4))

model.add(tf.keras.layers.Flatten())

model.add(tf.keras.layers.Dense(512, activation='relu'))

model.add(tf.keras.layers.Dense(1))

# add augmentations for the data
augment = {'featurewise_std_normalization' : True,'width_shift_range': 0.25, 'height_shift_range': 0.25, 'zoom_range' : 0.15, 'rotation_range' : 15, 'shear_range' : 0.1, 'horizontal_flip' : True}

# train the model and evaluate it with the test_data
train_and_evaluate(model, image_train, label_train, image_test, label_test, epochs=50, augment=augment)

# %% [markdown]
# loss: 327.1923
# RootMeanSquaredError: 18.0970
# val_loss: 479.3574
# val_RootMeanSquaredError: 21.9316
# ![image.png](attachment:image.png)

# %% [markdown]
# ## model 11
# - add preprocess

# %%
# create the CNN model by adding the layers
model = tf.keras.Sequential()

model.add(tf.keras.layers.Conv2D(32, (5, 5), input_shape=(128, 128, 3)))

model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
model.add(tf.keras.layers.Dropout(0.4))

model.add(tf.keras.layers.Conv2D(64, (3, 3)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
model.add(tf.keras.layers.Dropout(0.4))

model.add(tf.keras.layers.Conv2D(64, (3, 3)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
model.add(tf.keras.layers.Dropout(0.4))

model.add(tf.keras.layers.Flatten())

model.add(tf.keras.layers.Dense(512, activation='relu'))

model.add(tf.keras.layers.Dense(1))

# add augmentations and preprocess for the data
augment = {'featurewise_std_normalization' : True,'width_shift_range': 0.25, 'height_shift_range': 0.25, 'zoom_range' : 0.15, 'rotation_range' : 15, 'shear_range' : 0.1, 'horizontal_flip' : True}
preprocess = {'featurewise_center' : True}

# train the model and evaluate it with the test_data
train_and_evaluate(model, image_train, label_train, image_test, label_test, epochs=50, augment=augment, preprocess = preprocess)

# %% [markdown]
# loss: 279.6922
# RootMeanSquaredError: 16.7297
# val_loss: 577.5142
# val_RootMeanSquaredError: 24.0693
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Model 12
# - restart from beginning with own model

# %%
# create the CNN model by adding the layers
model = tf.keras.Sequential()

model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(128, 128, 3)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(tf.keras.layers.MaxPooling2D((2, 2)))

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(512, activation='relu'))
model.add(tf.keras.layers.Dense(1))

# add augmentations and preprocess for the data
augment = []
preprocess = {}

# train the model and evaluate it with the test_data
train_and_evaluate(model, image_train, label_train, image_test, label_test, epochs=50, augment=augment, preprocess = preprocess)

# %% [markdown]
# loss: 23.6816
# RootMeanSquaredError: 4.8682
# val_loss: 696.0492
# val_RootMeanSquaredError: 26.3499
# ![image.png](attachment:image.png)

# %% [markdown]
# ## model 13
# - adding preprocess
# - adding dropout

# %%
# create the CNN model by adding the layers
model = tf.keras.Sequential()

model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(128, 128, 3)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(tf.keras.layers.MaxPooling2D((2, 2)))

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dropout(0.4))
model.add(tf.keras.layers.Dense(512, activation='relu'))
model.add(tf.keras.layers.Dropout(0.4))
model.add(tf.keras.layers.Dense(1))

# add augmentations and preprocess for the data
augment = []
preprocess = {'featurewise_center' : True}

# train the model and evaluate it with the test_data
train_and_evaluate(model, image_train, label_train, image_test, label_test, epochs=50, augment=augment, preprocess = preprocess)

# %% [markdown]
# loss: 1203.4837
# RootMeanSquaredError: 34.6938
# val_loss: 1259.1765
# val_RootMeanSquaredError: 35.3895
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Model 14

# %%
# create the CNN model by adding the layers
model = tf.keras.Sequential()

model.add(tf.keras.layers.Conv2D(16, (3, 3), activation='relu', input_shape=(128, 128, 3)))
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu'))
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
model.add(tf.keras.layers.Conv2D(64, (3, 3), activation='relu'))
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
model.add(tf.keras.layers.Conv2D(128, (3, 3), activation='relu'))
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(1))


# add augmentations and preprocess for the data
augment = []
preprocess = {'samplewise_center' : True, 'samplewise_std_normalization' : True}

# train the model and evaluate it with the test_data
train_and_evaluate(model, image_train, label_train, image_test, label_test, epochs=50, augment=augment, preprocess = preprocess)

# %% [markdown]
# loss: 113.9725
# RootMeanSquaredError: 10.6756
# val_loss: 1308.9929
# val_RootMeanSquaredError: 36.1051
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Model 15

# %%
# create the CNN model by adding the layers
model = tf.keras.Sequential()

model.add(tf.keras.layers.Conv2D(128, (5, 5), padding='same', activation='relu', input_shape=(128, 128, 3)))
model.add(tf.keras.layers.MaxPooling2D((3, 3)))
model.add(tf.keras.layers.Conv2D(120, (4, 4), padding='same', activation='relu'))
model.add(tf.keras.layers.Conv2D(120, (4, 4), padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D((3, 3)))
model.add(tf.keras.layers.Conv2D(120, (3, 3), padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D((3, 3)))
model.add(tf.keras.layers.Conv2D(120, (3, 3), padding='same', activation='relu'))
model.add(tf.keras.layers.Conv2D(120, (3, 3), padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(300, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(300, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(1))


# add augmentations and preprocess for the data
augment = []
preprocess = {}

# train the model and evaluate it with the test_data
train_and_evaluate(model, image_train, label_train, image_test, label_test, epochs=50, augment=augment, preprocess = preprocess)

# %% [markdown]
# loss: 426.2253
# RootMeanSquaredError: 20.6373
# val_loss: 446.0563
# val_RootMeanSquaredError: 21.1693
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Model 15.2
# - added featurewise standard normalization

# %%
# create the CNN model by adding the layers
model = tf.keras.Sequential()

model.add(tf.keras.layers.Conv2D(128, (5, 5), padding='same', activation='relu', input_shape=(128, 128, 3)))
model.add(tf.keras.layers.MaxPooling2D((3, 3)))
model.add(tf.keras.layers.Conv2D(120, (4, 4), padding='same', activation='relu'))
model.add(tf.keras.layers.Conv2D(120, (4, 4), padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D((3, 3)))
model.add(tf.keras.layers.Conv2D(120, (3, 3), padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D((3, 3)))
model.add(tf.keras.layers.Conv2D(120, (3, 3), padding='same', activation='relu'))
model.add(tf.keras.layers.Conv2D(120, (3, 3), padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(300, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(300, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(1))


# add augmentations and preprocess for the data
augment = {'featurewise_std_normalization' : True}
preprocess = {}

# train the model and evaluate it with the test_data
train_and_evaluate(model, image_train, label_train, image_test, label_test, epochs=50, augment=augment, preprocess = preprocess)

# %% [markdown]
# loss: 424.9676
# RootMeanSquaredError: 20.6250
# val_loss: 440.3589
# val_RootMeanSquaredError: 21.0425
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Model 15.3
# - ???

# %%
# create the CNN model by adding the layers
model = tf.keras.Sequential()

model.add(tf.keras.layers.Conv2D(128, (5, 5), padding='same', activation='relu', input_shape=(128, 128, 3)))
model.add(tf.keras.layers.MaxPooling2D((3, 3)))
model.add(tf.keras.layers.Conv2D(128, (4, 4), padding='same', activation='relu'))
model.add(tf.keras.layers.Conv2D(128, (4, 4), padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D((3, 3)))
model.add(tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D((3, 3)))
model.add(tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(300, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(300, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(1))


# add augmentations and preprocess for the data
augment = {}
preprocess = {'featurewise_center' : True, 'featurewise_std_normalization' : True}

# train the model and evaluate it with the test_data
train_and_evaluate(model, image_train, label_train, image_test, label_test, epochs=50, augment=augment, preprocess = preprocess)

# %% [markdown]
# loss: 424.8141
# RootMeanSquaredError: 20.6179
# val_loss: 445.0954
# val_RootMeanSquaredError: 21.1394
# ![image.png](attachment:image.png)

# %% [markdown]
# # Augmentation and preprocessing

# %% [markdown]
# ## Model 1
# - baseline

# %%
augment = {}
preprocess = {}

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Model 2
# - added batch normalization

# %% [markdown]
# loss: 127.4313
# RootMeanSquaredError: 11.2946
# val_loss: 515.9401
# val_RootMeanSquaredError: 22.6914
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Model 3
# - with samplewise standard normalization

# %% [markdown]
# loss: 93.1838
# RootMeanSquaredError: 9.6257
# val_loss: 8327.2218
# val_RootMeanSquaredError: 91.2836
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Model 4
# - With featurewise standard normalization

# %% [markdown]
# loss: 57.5324 - RootMeanSquaredError: 7.5885 - val_loss: 3512.3834 - val_RootMeanSquaredError: 59.3228
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Model 5
# - with featurewise center

# %% [markdown]
# loss: 39.9575 - RootMeanSquaredError: 6.3154 - val_loss: 580.6968 - val_RootMeanSquaredError: 24.0230
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Model 6
# - with horizontal flip

# %% [markdown]
# loss: 44.4082 - RootMeanSquaredError: 6.6649 - val_loss: 555.8364 - val_RootMeanSquaredError: 23.5506
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Model 7
# - with height shift range (0.25)

# %% [markdown]
# loss: 47.5680 - RootMeanSquaredError: 6.8816 - val_loss: 571.2801 - val_RootMeanSquaredError: 23.8388
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Model 8
# - with width shift range (0.25)

# %% [markdown]
# loss: 42.4089 - RootMeanSquaredError: 6.5041 - val_loss: 586.6193 - val_RootMeanSquaredError: 24.1567
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Model 9
# - with zoom range (0.15)

# %% [markdown]
# loss: 49.1538 - RootMeanSquaredError: 7.0107 - val_loss: 641.8535 - val_RootMeanSquaredError: 25.3178
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Model 10
# - with shear range (0.1)

# %% [markdown]
# loss: 152.3215 - RootMeanSquaredError: 11.0419 - val_loss: 581.3567 - val_RootMeanSquaredError: 24.0300
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Model 11
# - with rotation range (15)

# %% [markdown]
# loss: 47.8844 - RootMeanSquaredError: 6.9217 - val_loss: 516.0542 - val_RootMeanSquaredError: 22.6714
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Model 12
# - with brightness range (0.5-1.5)

# %% [markdown]
# loss: 70.6381 - RootMeanSquaredError: 8.4061 - val_loss: 507.2503 - val_RootMeanSquaredError: 22.5914
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Model 13
# - with samplewise center

# %% [markdown]
# loss: 112.8812 - RootMeanSquaredError: 10.6295 - val_loss: 1092.9257 - val_RootMeanSquaredError: 33.0664
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Model 14
# - with rescale (1/255)

# %% [markdown]
# loss: 44.8503 - RootMeanSquaredError: 6.6964 - val_loss: 596.9424 - val_RootMeanSquaredError: 24.3556
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Model 15
# - with vertical flip

# %% [markdown]
# loss: 47.3109 - RootMeanSquaredError: 6.8764 - val_loss: 559.4761 - val_RootMeanSquaredError: 23.6597
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Model 16
# - with height and width shift range

# %% [markdown]
# loss: 49.5605 - RootMeanSquaredError: 7.0359 - val_loss: 534.9913 - val_RootMeanSquaredError: 23.1715
# ![image.png](attachment:image.png)
