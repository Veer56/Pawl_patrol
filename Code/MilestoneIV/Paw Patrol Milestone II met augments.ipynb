# %% [markdown]
# ## Preparing the data

# %%
import os
import cv2
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras import regularizers

# %%
# change working directory to model folder
os.chdir("C:\\Users\\brian\\Desktop\\minor\\AI project\\model")

# save the data from the csv file and divide Pawpularity score by 100
train_data = pd.read_csv('petfinder-pawpularity-score/train.csv')
# train_data = train_data[train_data.Pawpularity != 100]

# check if the data was read correctly and if there are NaN values
display(train_data.head(5))
print(f'NaN amount: {train_data.isnull().sum().sum()}')
# Out:
#                                  Id  Subject Focus  Eyes  Face  Near  Action  \
# 0  0007de18844b0dbbb5e1f607da0606e0              0     1     1     1       0
# 1  0009c66b9439883ba2750fb825e1d7db              0     1     1     0       0
# 2  0013fd999caf9a3efe1352ca1b0d937e              0     1     1     1       0
# 3  0018df346ac9c1d8413cfcc888ca8246              0     1     1     1       0
# 4  001dc955e10590d3ca4673f034feeef2              0     0     0     1       0
#
#    Accessory  Group  Collage  Human  Occlusion  Info  Blur  Pawpularity
# 0          0      1        0      0          0     0     0           63
# 1          0      0        0      0          0     0     0           42
# 2          0      0        0      1          1     0     0           28
# 3          0      0        0      0          0     0     0           15
# 4          0      1        0      0          0     0     0           72
# NaN amount: 0

# %%
def load_images_from_folder(folder, data = [], size=64):

    samples = len(data)
    images = [None] * samples


    for count, filename in enumerate(os.listdir(folder)):
        name = filename.strip('.jpg')
        index = train_data[train_data['Id']==name].index.item()

        img = cv2.resize(cv2.imread(os.path.join(folder,filename)), (size, size))

        if img is not None:
            images[index] = img

        if count % 1000 == 0:
            print(f"{round(count / samples *100, 0)}%")

    return np.array(images), np.array(data['Pawpularity']), np.array(data['Id'])

data_images, data_labels, data_names = load_images_from_folder('petfinder-pawpularity-score/train', data = train_data)

print(f'Training labels loaded: {data_images.shape}')
# Out:
# 0.0%
# 10.0%
# 20.0%
# 30.0%
# 40.0%
# 50.0%
# 61.0%
# 71.0%
# 81.0%
# 91.0%
# Training labels loaded: (9912, 64, 64, 3)

# %% [markdown]
# ## Making the image model

# %%
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models, preprocessing, utils
import tensorflow as tf
from tensorflow.keras import regularizers
from tensorflow.keras.layers import LeakyReLU

# %%
def train_and_evaluate(model, train_x, train_y, preprocess={}, epochs=20, augment={}, folds = 5):
    ''' Make the model to train and evaluate the data'''

    from sklearn.model_selection import KFold
    kfold = KFold(n_splits=folds)

    cv_scores= [] 

    for train, test in kfold.split(train_x, train_y):
      # compile the model using adam as optimizer with mean squared error as loss function
        model.compile(optimizer='adam',
                loss='MSE',
                metrics=['RootMeanSquaredError'])

        train_gen = preprocessing.image.ImageDataGenerator(preprocess, augment)
        train_gen.fit(train_x[train]) 

        val_gen = preprocessing.image.ImageDataGenerator(**preprocess)
        val_gen.fit(train_x[test])

      # estimate the model using the compile 
        history = model.fit(train_gen.flow(train_x[train], np.array(train_y)[train]), epochs=epochs, 
                          validation_data=val_gen.flow(train_x[test], np.array(train_y)[test]))

        fig, axs = plt.subplots(1,2,figsize=(20,5)) 

      # plot the learning curves
        for i, metric in enumerate(['loss', 'RootMeanSquaredError']):
            axs[i].plot(history.history[metric])
            axs[i].plot(history.history['val_'+metric])
            axs[i].legend(['training', 'validation'], loc='best')

            axs[i].set_title('Model '+metric)
            axs[i].set_ylabel(metric)
            axs[i].set_xlabel('epoch')

        plt.show()

        score = model.evaluate(val_gen.flow(train_x[test], np.array(train_y)[test]))[1]

        cv_scores.append(score)

        print('cv_scores:', cv_scores)
    print('Mean RMSE:', np.mean(cv_scores))

# %%
''' First model with 3 hidden layers, dropout, batchnormalization, activity regularizer,
  featurewise center and featurewise std normalization'''


# activity_regularizer=regularizers.l2(1e-3)
# kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4),

model=tf.keras.Sequential()

model.add(tf.keras.layers.Conv2D(64,(3,3),activation='relu',input_shape=(64,64,3),padding='same'))
model.add(tf.keras.layers.MaxPool2D((2,2)))
#model.add(layers.BatchNormalization())

model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.Conv2D(128,(3,3),activation='relu',padding='same'))
model.add(tf.keras.layers.MaxPool2D((2,2)))
model.add(layers.BatchNormalization())

model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.Conv2D(256,(3,3),activation='relu',padding='same'))
model.add(tf.keras.layers.MaxPool2D((2,2)))
model.add(layers.BatchNormalization())

model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.Conv2D(512,(3,3),activation='relu',padding='same',activity_regularizer=regularizers.l2(1e-4)))
model.add(tf.keras.layers.MaxPool2D((2,2)))
model.add(layers.BatchNormalization())

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(256, activation='relu'))
model.add(tf.keras.layers.Dropout(0.7))
model.add(tf.keras.layers.Dense(128,activation='relu'))
model.add(tf.keras.layers.Dropout(0.7))
model.add(tf.keras.layers.Dense(64,activation='relu',activity_regularizer=regularizers.l2(1e-1)))
model.add(tf.keras.layers.Dropout(0.7))
model.add(tf.keras.layers.Dense(1,activation=None))

preprocess = {'featurewise_center': True, 'featurewise_std_normalization': True}
augment = {'rotation_range' : 30, 'vertical_flip' : True, 'width_shift_range' : 0.25, 'height_shift_range' : 0.25}

# train the model and evaluate it with the test_data

train_and_evaluate(model, data_images, data_labels, preprocess=preprocess, epochs=20, augment = augment)
# Out:
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 248 steps, validate for 62 steps
# Epoch 1/20
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# 248/248 [==============================] - 5s 18ms/step - loss: 1210.2454 - RootMeanSquaredError: 31.3457 - val_loss: 1276.4840 - val_RootMeanSquaredError: 34.8638
# Epoch 2/20
# 248/248 [==============================] - 3s 14ms/step - loss: 1059.5138 - RootMeanSquaredError: 29.5824 - val_loss: 1205.0420 - val_RootMeanSquaredError: 33.4415
# Epoch 3/20
# 248/248 [==============================] - 3s 14ms/step - loss: 982.2272 - RootMeanSquaredError: 28.6868 - val_loss: 1208.9112 - val_RootMeanSquaredError: 34.0704
# Epoch 4/20
# 248/248 [==============================] - 3s 14ms/step - loss: 981.9742 - RootMeanSquaredError: 28.9752 - val_loss: 1173.5118 - val_RootMeanSquaredError: 33.5769
# Epoch 5/20
# 248/248 [==============================] - 3s 14ms/step - loss: 915.2837 - RootMeanSquaredError: 28.1694 - val_loss: 1198.5850 - val_RootMeanSquaredError: 33.4540
# Epoch 6/20
# 248/248 [==============================] - 3s 14ms/step - loss: 873.8623 - RootMeanSquaredError: 27.6674 - val_loss: 1032.1263 - val_RootMeanSquaredError: 30.8862
# Epoch 7/20
# 248/248 [==============================] - 3s 14ms/step - loss: 852.1612 - RootMeanSquaredError: 27.5769 - val_loss: 923.2711 - val_RootMeanSquaredError: 29.3525
# Epoch 8/20
# 248/248 [==============================] - 3s 14ms/step - loss: 800.4107 - RootMeanSquaredError: 26.8564 - val_loss: 1024.6637 - val_RootMeanSquaredError: 31.3639
# Epoch 9/20
# 248/248 [==============================] - 3s 14ms/step - loss: 757.5521 - RootMeanSquaredError: 26.3085 - val_loss: 746.5012 - val_RootMeanSquaredError: 26.6265
# Epoch 10/20
# 248/248 [==============================] - 3s 14ms/step - loss: 721.1685 - RootMeanSquaredError: 25.8778 - val_loss: 627.4711 - val_RootMeanSquaredError: 24.2396
# Epoch 11/20
# 248/248 [==============================] - 3s 14ms/step - loss: 677.2253 - RootMeanSquaredError: 25.1362 - val_loss: 513.7192 - val_RootMeanSquaredError: 21.8213
# Epoch 12/20
# 248/248 [==============================] - 3s 14ms/step - loss: 630.6334 - RootMeanSquaredError: 24.3533 - val_loss: 525.3705 - val_RootMeanSquaredError: 22.1211
# Epoch 13/20
# 248/248 [==============================] - 3s 14ms/step - loss: 594.5561 - RootMeanSquaredError: 23.7734 - val_loss: 579.8540 - val_RootMeanSquaredError: 23.3811
# Epoch 14/20
# 248/248 [==============================] - 3s 14ms/step - loss: 567.2893 - RootMeanSquaredError: 23.3335 - val_loss: 492.7038 - val_RootMeanSquaredError: 21.7026
# Epoch 15/20
# 248/248 [==============================] - 3s 14ms/step - loss: 539.7407 - RootMeanSquaredError: 22.8335 - val_loss: 462.7812 - val_RootMeanSquaredError: 21.0592
# Epoch 16/20
# 248/248 [==============================] - 3s 14ms/step - loss: 515.2268 - RootMeanSquaredError: 22.3401 - val_loss: 457.1403 - val_RootMeanSquaredError: 20.9584
# Epoch 17/20
# 248/248 [==============================] - 3s 14ms/step - loss: 510.9158 - RootMeanSquaredError: 22.2833 - val_loss: 453.5797 - val_RootMeanSquaredError: 20.9304
# Epoch 18/20
# 248/248 [==============================] - 3s 14ms/step - loss: 502.7263 - RootMeanSquaredError: 22.1273 - val_loss: 448.2100 - val_RootMeanSquaredError: 20.8387
# Epoch 19/20
# 248/248 [==============================] - 3s 14ms/step - loss: 498.5775 - RootMeanSquaredError: 22.0325 - val_loss: 444.2953 - val_RootMeanSquaredError: 20.7324
# Epoch 20/20
# 248/248 [==============================] - 3s 14ms/step - loss: 501.4588 - RootMeanSquaredError: 22.1090 - val_loss: 445.2146 - val_RootMeanSquaredError: 20.7795
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 62/62 [==============================] - 0s 4ms/step - loss: 445.0579 - RootMeanSquaredError: 20.7795
# cv_scores: [20.779518]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 248 steps, validate for 62 steps
# Epoch 1/20
# 248/248 [==============================] - 5s 20ms/step - loss: 504.7141 - RootMeanSquaredError: 22.1923 - val_loss: 448.7042 - val_RootMeanSquaredError: 20.8875
# Epoch 2/20
# 248/248 [==============================] - 3s 14ms/step - loss: 499.8135 - RootMeanSquaredError: 22.0927 - val_loss: 494.3394 - val_RootMeanSquaredError: 21.9385
# Epoch 3/20
# 248/248 [==============================] - 3s 14ms/step - loss: 500.8568 - RootMeanSquaredError: 22.1326 - val_loss: 449.8011 - val_RootMeanSquaredError: 20.9557
# Epoch 4/20
# 248/248 [==============================] - 3s 14ms/step - loss: 496.5588 - RootMeanSquaredError: 22.0412 - val_loss: 445.6693 - val_RootMeanSquaredError: 20.8470
# Epoch 5/20
# 248/248 [==============================] - 3s 14ms/step - loss: 500.7571 - RootMeanSquaredError: 22.1446 - val_loss: 444.8653 - val_RootMeanSquaredError: 20.8401
# Epoch 6/20
# 248/248 [==============================] - 3s 14ms/step - loss: 499.2038 - RootMeanSquaredError: 22.1149 - val_loss: 449.8658 - val_RootMeanSquaredError: 20.9764
# Epoch 7/20
# 248/248 [==============================] - 3s 14ms/step - loss: 498.0028 - RootMeanSquaredError: 22.0941 - val_loss: 447.1789 - val_RootMeanSquaredError: 20.9171
# Epoch 8/20
# 248/248 [==============================] - 3s 14ms/step - loss: 496.4453 - RootMeanSquaredError: 22.0614 - val_loss: 447.2931 - val_RootMeanSquaredError: 20.9227
# Epoch 9/20
# 248/248 [==============================] - 3s 14ms/step - loss: 499.5718 - RootMeanSquaredError: 22.1364 - val_loss: 447.5085 - val_RootMeanSquaredError: 20.9348
# Epoch 10/20
# 248/248 [==============================] - 3s 14ms/step - loss: 500.3219 - RootMeanSquaredError: 22.1586 - val_loss: 446.1222 - val_RootMeanSquaredError: 20.9037
# Epoch 11/20
# 248/248 [==============================] - 3s 14ms/step - loss: 489.3603 - RootMeanSquaredError: 21.9111 - val_loss: 446.0017 - val_RootMeanSquaredError: 20.9064
# Epoch 12/20
# 248/248 [==============================] - 3s 14ms/step - loss: 496.9626 - RootMeanSquaredError: 22.0913 - val_loss: 446.4054 - val_RootMeanSquaredError: 20.9211
# Epoch 13/20
# 248/248 [==============================] - 3s 14ms/step - loss: 499.7788 - RootMeanSquaredError: 22.1580 - val_loss: 444.8576 - val_RootMeanSquaredError: 20.8828
# Epoch 14/20
# 248/248 [==============================] - 3s 14ms/step - loss: 491.2093 - RootMeanSquaredError: 21.9641 - val_loss: 446.7788 - val_RootMeanSquaredError: 20.9362
# Epoch 15/20
# 248/248 [==============================] - 3s 14ms/step - loss: 495.0054 - RootMeanSquaredError: 22.0518 - val_loss: 446.7517 - val_RootMeanSquaredError: 20.9372
# Epoch 16/20
# 248/248 [==============================] - 3s 14ms/step - loss: 487.1688 - RootMeanSquaredError: 21.8771 - val_loss: 444.9967 - val_RootMeanSquaredError: 20.8942
# Epoch 17/20
# 248/248 [==============================] - 4s 14ms/step - loss: 492.1863 - RootMeanSquaredError: 21.9926 - val_loss: 445.2109 - val_RootMeanSquaredError: 20.9042
# Epoch 18/20
# 248/248 [==============================] - 3s 14ms/step - loss: 496.9813 - RootMeanSquaredError: 22.1048 - val_loss: 443.8124 - val_RootMeanSquaredError: 20.8698
# Epoch 19/20
# 248/248 [==============================] - 3s 14ms/step - loss: 489.8419 - RootMeanSquaredError: 21.9474 - val_loss: 446.4693 - val_RootMeanSquaredError: 20.9419
# Epoch 20/20
# 248/248 [==============================] - 3s 14ms/step - loss: 488.5807 - RootMeanSquaredError: 21.9207 - val_loss: 444.3426 - val_RootMeanSquaredError: 20.8899
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 62/62 [==============================] - 0s 4ms/step - loss: 444.5723 - RootMeanSquaredError: 20.8899
# cv_scores: [20.779518, 20.889933]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 248 steps, validate for 62 steps
# Epoch 1/20
# 248/248 [==============================] - 4s 18ms/step - loss: 490.1443 - RootMeanSquaredError: 21.9636 - val_loss: 450.1168 - val_RootMeanSquaredError: 21.0227
# Epoch 2/20
# 248/248 [==============================] - 3s 14ms/step - loss: 485.8330 - RootMeanSquaredError: 21.8686 - val_loss: 448.9698 - val_RootMeanSquaredError: 20.9957
# Epoch 3/20
# 248/248 [==============================] - 3s 14ms/step - loss: 487.4749 - RootMeanSquaredError: 21.9076 - val_loss: 448.5334 - val_RootMeanSquaredError: 20.9876
# Epoch 4/20
# 248/248 [==============================] - 3s 14ms/step - loss: 484.0247 - RootMeanSquaredError: 21.8317 - val_loss: 448.5648 - val_RootMeanSquaredError: 20.9919
# Epoch 5/20
# 248/248 [==============================] - 3s 14ms/step - loss: 489.0240 - RootMeanSquaredError: 21.9468 - val_loss: 451.9139 - val_RootMeanSquaredError: 21.0796
# Epoch 6/20
# 248/248 [==============================] - 4s 14ms/step - loss: 484.4526 - RootMeanSquaredError: 21.8471 - val_loss: 448.8713 - val_RootMeanSquaredError: 21.0036
# Epoch 7/20
# 248/248 [==============================] - 3s 14ms/step - loss: 485.2628 - RootMeanSquaredError: 21.8649 - val_loss: 448.9465 - val_RootMeanSquaredError: 21.0073
# Epoch 8/20
# 248/248 [==============================] - 4s 14ms/step - loss: 485.7105 - RootMeanSquaredError: 21.8770 - val_loss: 447.9151 - val_RootMeanSquaredError: 20.9826
# Epoch 9/20
# 248/248 [==============================] - 3s 14ms/step - loss: 485.7809 - RootMeanSquaredError: 21.8797 - val_loss: 448.2177 - val_RootMeanSquaredError: 20.9918
# Epoch 10/20
# 248/248 [==============================] - 3s 14ms/step - loss: 483.6801 - RootMeanSquaredError: 21.8337 - val_loss: 448.4557 - val_RootMeanSquaredError: 20.9987
# Epoch 11/20
# 248/248 [==============================] - 3s 14ms/step - loss: 488.6177 - RootMeanSquaredError: 21.9467 - val_loss: 449.6216 - val_RootMeanSquaredError: 21.0301
# Epoch 12/20
# 248/248 [==============================] - 3s 14ms/step - loss: 481.3130 - RootMeanSquaredError: 21.7796 - val_loss: 447.1527 - val_RootMeanSquaredError: 20.9681
# Epoch 13/20
# 248/248 [==============================] - 3s 14ms/step - loss: 488.9409 - RootMeanSquaredError: 21.9582 - val_loss: 448.2553 - val_RootMeanSquaredError: 20.9978
# Epoch 14/20
# 248/248 [==============================] - 3s 14ms/step - loss: 479.8089 - RootMeanSquaredError: 21.7492 - val_loss: 448.5742 - val_RootMeanSquaredError: 21.0075
# Epoch 15/20
# 248/248 [==============================] - 4s 14ms/step - loss: 484.8950 - RootMeanSquaredError: 21.8658 - val_loss: 448.3995 - val_RootMeanSquaredError: 21.0043
# Epoch 16/20
# 248/248 [==============================] - 3s 14ms/step - loss: 479.6144 - RootMeanSquaredError: 21.7463 - val_loss: 448.9150 - val_RootMeanSquaredError: 21.0196
# Epoch 17/20
# 248/248 [==============================] - 4s 14ms/step - loss: 477.2059 - RootMeanSquaredError: 21.6939 - val_loss: 447.5239 - val_RootMeanSquaredError: 20.9859
# Epoch 18/20
# 248/248 [==============================] - 3s 14ms/step - loss: 478.1956 - RootMeanSquaredError: 21.7164 - val_loss: 447.7955 - val_RootMeanSquaredError: 20.9951
# Epoch 19/20
# 248/248 [==============================] - 3s 14ms/step - loss: 484.3774 - RootMeanSquaredError: 21.8618 - val_loss: 448.7319 - val_RootMeanSquaredError: 21.0207
# Epoch 20/20
# 248/248 [==============================] - 3s 14ms/step - loss: 478.6024 - RootMeanSquaredError: 21.7311 - val_loss: 448.8317 - val_RootMeanSquaredError: 21.0247
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 62/62 [==============================] - 0s 4ms/step - loss: 448.5756 - RootMeanSquaredError: 21.0247
# cv_scores: [20.779518, 20.889933, 21.024744]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 248 steps, validate for 62 steps
# Epoch 1/20
# 248/248 [==============================] - 5s 18ms/step - loss: 490.3336 - RootMeanSquaredError: 21.9982 - val_loss: 414.0496 - val_RootMeanSquaredError: 20.1904
# Epoch 2/20
# 248/248 [==============================] - 3s 14ms/step - loss: 488.4954 - RootMeanSquaredError: 21.9557 - val_loss: 414.1156 - val_RootMeanSquaredError: 20.1938
# Epoch 3/20
# 248/248 [==============================] - 3s 14ms/step - loss: 481.2897 - RootMeanSquaredError: 21.7914 - val_loss: 414.1969 - val_RootMeanSquaredError: 20.1973
# Epoch 4/20
# 248/248 [==============================] - 3s 14ms/step - loss: 491.0441 - RootMeanSquaredError: 22.0165 - val_loss: 413.1824 - val_RootMeanSquaredError: 20.1708
# Epoch 5/20
# 248/248 [==============================] - 3s 14ms/step - loss: 483.9291 - RootMeanSquaredError: 21.8532 - val_loss: 412.5727 - val_RootMeanSquaredError: 20.1567
# Epoch 6/20
# 248/248 [==============================] - 3s 14ms/step - loss: 484.6616 - RootMeanSquaredError: 21.8727 - val_loss: 414.1303 - val_RootMeanSquaredError: 20.2009
# Epoch 7/20
# 248/248 [==============================] - 3s 14ms/step - loss: 483.1142 - RootMeanSquaredError: 21.8401 - val_loss: 413.6690 - val_RootMeanSquaredError: 20.1896
# Epoch 8/20
# 248/248 [==============================] - 3s 14ms/step - loss: 483.6412 - RootMeanSquaredError: 21.8528 - val_loss: 413.6631 - val_RootMeanSquaredError: 20.1899
# Epoch 9/20
# 248/248 [==============================] - 3s 14ms/step - loss: 487.1388 - RootMeanSquaredError: 21.9340 - val_loss: 413.5606 - val_RootMeanSquaredError: 20.1891
# Epoch 10/20
# 248/248 [==============================] - 3s 14ms/step - loss: 487.7581 - RootMeanSquaredError: 21.9481 - val_loss: 413.3964 - val_RootMeanSquaredError: 20.1865
# Epoch 11/20
# 248/248 [==============================] - 3s 14ms/step - loss: 481.4198 - RootMeanSquaredError: 21.8053 - val_loss: 412.5694 - val_RootMeanSquaredError: 20.1646
# Epoch 12/20
# 248/248 [==============================] - 3s 14ms/step - loss: 481.6899 - RootMeanSquaredError: 21.8138 - val_loss: 412.4466 - val_RootMeanSquaredError: 20.1641
# Epoch 13/20
# 248/248 [==============================] - 3s 14ms/step - loss: 483.8653 - RootMeanSquaredError: 21.8634 - val_loss: 411.9348 - val_RootMeanSquaredError: 20.1514
# Epoch 14/20
# 248/248 [==============================] - 3s 14ms/step - loss: 484.4935 - RootMeanSquaredError: 21.8805 - val_loss: 412.5738 - val_RootMeanSquaredError: 20.1704
# Epoch 15/20
# 248/248 [==============================] - 3s 14ms/step - loss: 479.0712 - RootMeanSquaredError: 21.7563 - val_loss: 412.7988 - val_RootMeanSquaredError: 20.1774
# Epoch 16/20
# 248/248 [==============================] - 3s 14ms/step - loss: 483.2155 - RootMeanSquaredError: 21.8521 - val_loss: 412.2493 - val_RootMeanSquaredError: 20.1638
# Epoch 17/20
# 248/248 [==============================] - 3s 14ms/step - loss: 484.8321 - RootMeanSquaredError: 21.8895 - val_loss: 411.9963 - val_RootMeanSquaredError: 20.1580
# Epoch 18/20
# 248/248 [==============================] - 3s 14ms/step - loss: 483.2024 - RootMeanSquaredError: 21.8545 - val_loss: 411.9910 - val_RootMeanSquaredError: 20.1599
# Epoch 19/20
# 248/248 [==============================] - 4s 14ms/step - loss: 481.9534 - RootMeanSquaredError: 21.8249 - val_loss: 411.8713 - val_RootMeanSquaredError: 20.1570
# Epoch 20/20
# 248/248 [==============================] - 3s 14ms/step - loss: 482.3496 - RootMeanSquaredError: 21.8365 - val_loss: 412.7830 - val_RootMeanSquaredError: 20.1822
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 62/62 [==============================] - 0s 4ms/step - loss: 412.7360 - RootMeanSquaredError: 20.1822
# cv_scores: [20.779518, 20.889933, 21.024744, 20.182224]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 248 steps, validate for 62 steps
# Epoch 1/20
# 248/248 [==============================] - 5s 18ms/step - loss: 478.4788 - RootMeanSquaredError: 21.7527 - val_loss: 424.3590 - val_RootMeanSquaredError: 20.4620
# Epoch 2/20
# 248/248 [==============================] - 3s 14ms/step - loss: 474.5073 - RootMeanSquaredError: 21.6603 - val_loss: 425.1088 - val_RootMeanSquaredError: 20.483685 - RootMeanSquaredErr - ETA: 0s - loss: 484.1000 - RootMeanSquared
# Epoch 3/20
# 248/248 [==============================] - 3s 14ms/step - loss: 474.3871 - RootMeanSquaredError: 21.6613 - val_loss: 423.8934 - val_RootMeanSquaredError: 20.4520
# Epoch 4/20
# 248/248 [==============================] - 3s 14ms/step - loss: 479.5602 - RootMeanSquaredError: 21.7792 - val_loss: 423.4858 - val_RootMeanSquaredError: 20.4432
# Epoch 5/20
# 248/248 [==============================] - 3s 14ms/step - loss: 475.7740 - RootMeanSquaredError: 21.6908 - val_loss: 424.3402 - val_RootMeanSquaredError: 20.4664
# Epoch 6/20
# 248/248 [==============================] - 3s 14ms/step - loss: 472.3085 - RootMeanSquaredError: 21.6154 - val_loss: 423.7960 - val_RootMeanSquaredError: 20.4528
# Epoch 7/20
# 248/248 [==============================] - 3s 14ms/step - loss: 469.9407 - RootMeanSquaredError: 21.5593 - val_loss: 424.2487 - val_RootMeanSquaredError: 20.4665
# Epoch 8/20
# 248/248 [==============================] - 3s 14ms/step - loss: 477.3876 - RootMeanSquaredError: 21.7327 - val_loss: 424.0637 - val_RootMeanSquaredError: 20.4618
# Epoch 9/20
# 248/248 [==============================] - 3s 14ms/step - loss: 472.9416 - RootMeanSquaredError: 21.6319 - val_loss: 424.1820 - val_RootMeanSquaredError: 20.4670
# Epoch 10/20
# 248/248 [==============================] - 3s 14ms/step - loss: 477.5290 - RootMeanSquaredError: 21.7380 - val_loss: 423.4683 - val_RootMeanSquaredError: 20.4485
# Epoch 11/20
# 248/248 [==============================] - 3s 14ms/step - loss: 474.9745 - RootMeanSquaredError: 21.6799 - val_loss: 423.7053 - val_RootMeanSquaredError: 20.4562
# Epoch 12/20
# 248/248 [==============================] - 3s 14ms/step - loss: 471.2679 - RootMeanSquaredError: 21.5973 - val_loss: 423.4963 - val_RootMeanSquaredError: 20.4531
# Epoch 13/20
# 248/248 [==============================] - 3s 14ms/step - loss: 475.2692 - RootMeanSquaredError: 21.6899 - val_loss: 424.4540 - val_RootMeanSquaredError: 20.4783
# Epoch 14/20
# 248/248 [==============================] - 3s 14ms/step - loss: 466.3443 - RootMeanSquaredError: 21.4827 - val_loss: 424.5370 - val_RootMeanSquaredError: 20.4811
# Epoch 15/20
# 248/248 [==============================] - 3s 14ms/step - loss: 474.2977 - RootMeanSquaredError: 21.6701 - val_loss: 422.9196 - val_RootMeanSquaredError: 20.4396
# Epoch 16/20
# 248/248 [==============================] - 3s 14ms/step - loss: 473.3063 - RootMeanSquaredError: 21.6440 - val_loss: 422.8747 - val_RootMeanSquaredError: 20.4391
# Epoch 17/20
# 248/248 [==============================] - 3s 14ms/step - loss: 472.0922 - RootMeanSquaredError: 21.6189 - val_loss: 423.2644 - val_RootMeanSquaredError: 20.4503
# Epoch 18/20
# 248/248 [==============================] - 3s 14ms/step - loss: 470.5859 - RootMeanSquaredError: 21.5851 - val_loss: 423.3014 - val_RootMeanSquaredError: 20.4526
# Epoch 19/20
# 248/248 [==============================] - 3s 14ms/step - loss: 471.4696 - RootMeanSquaredError: 21.6068 - val_loss: 423.0997 - val_RootMeanSquaredError: 20.4479
# Epoch 20/20
# 248/248 [==============================] - 3s 14ms/step - loss: 477.2542 - RootMeanSquaredError: 21.7405 - val_loss: 423.3886 - val_RootMeanSquaredError: 20.4566
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 62/62 [==============================] - 0s 4ms/step - loss: 423.1496 - RootMeanSquaredError: 20.4566
# cv_scores: [20.779518, 20.889933, 21.024744, 20.182224, 20.456642]
# Mean RMSE: 20.666613

# %%
predictions = model.predict(data_images)
print(predictions[np.argmax(predictions)])
print(predictions[np.argmin(predictions)])
# Out:
# [67.189964]
# [11.914236]

# %%
import seaborn as sns
import matplotlib.pyplot as plt


sns.boxplot(predictions)
plt.show()
# Out:
# C:\Users\brian\anaconda3\envs\Jupyter\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# This dataset is from a competition in which you have to estimate the 8 images below, these are our scores as of now.

# %%
test_images = []
test_names = []

# iterate over the test images
for filename in os.listdir('petfinder-pawpularity-score/test'):
    
    # get the names of the test images and save these in the list
    name = filename.strip('.jpg')
    test_names.append(name)
    
    # save the images 
    img = cv2.imread(os.path.join('petfinder-pawpularity-score/test',filename))
    if img is not None:
        test_images.append(img)

# %%
# convert the list of images to an array
test_images = np.array(test_images)

# use the model to predict the pawpularity scores of the test images
model.predict(data_images)
